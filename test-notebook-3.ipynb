# %%
from dotenv import load_dotenv
import os
from src.split_pdf_by_number_of_pages import split_pdf
from src.ocr_pdf import ocr_pdf
from src.export_pdf_to_docx import export_pdf_to_docx
from src.combine_pdf import combine_pdf
from src.get_pdf_properties import get_pdf_properties
load_dotenv()
# Out:
# True

# %%
get_pdf_properties(input_pdf_name="input/python_dashboard_with_plotly_and_dash.pdf")
# Out:
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting PDF_PROPERTIES job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# Size of the specified PDF file:36110.0 KB
# Version of the specified PDF file:1.7
# Page count of the specified PDF file:133
# {'document': {'is_linearized': False,
#   'is_tagged': False,
#   'is_portfolio': False,
#   'is_certified': False,
#   'is_encrypted': False,
#   'info_dict': {'CreationDate': "D:20230704122003+05'30'",
#    'Producer': 'Microsoft: Print To PDF',
#    'ModDate': "D:20230704122003+05'30'",
# ...

# %%
ocr_pdf(input_pdf_name='input/Reinforcement Learning - With Open AI, TensorFlow and Keras Using Python.pdf')
# Out:
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# Inside ocr_pdf function
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting OCR_PDF job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting content
# 'data/ocr-20240823110052.pdf'

# %%
import json
data = get_pdf_properties(input_pdf_name='input/Head First HTML and CSS - 2nd Ed.pdf')
with open('data/pdf_properties_head_first.json', 'w') as file:
    json.dump(data, file, indent=4)
# Out:
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting PDF_PROPERTIES job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# Size of the specified PDF file:100661.58 KB
# Version of the specified PDF file:1.6
# Page count of the specified PDF file:764

# %%
data.get("document").get("page_count")
# Out:
# 764

# %%
ocr_pdf(input_pdf_name='input/Head First HTML and CSS - 2nd Ed.pdf')
# Out:
# Inside ocr_pdf function
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting OCR_PDF job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# ERROR:root:Exception encountered while executing operation: description =The number of pages allowed in a document for conversion exceeded.; requestId=e6c95c51-6119-11ef-b576-8c8caaeca1cb; requestTrackingId=e8a5279d-f31f-4dfa-9e56-f516a932bb5b; statusCode=400; errorCode=PAGE_LIMIT_EXCEEDED
# Traceback (most recent call last):
#   File "c:\Users\Vijaya Nandini\Documents\2024_adobe_pdf_apis\adobe-api-pdf-services-poc\src\ocr_pdf.py", line 69, in ocr_pdf
#     pdf_services_response = pdf_services.get_job_result(location, OCRPDFResult)
# ...

# %%
split_pdf(input_pdf_name='input/Reinforcement Learning - With Open AI, TensorFlow and Keras Using Python.pdf',page_count=10)
# Out:
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# Inside split_pdf function
# Client ID: 4cbbcd7f2f5647399864a8d18b360804
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting SPLIT_PDF job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting content
# ...

# %%
pdfs = ['data/split-20240823111724-0.pdf',
 'data/split-20240823111724-1.pdf',
 'data/split-20240823111724-2.pdf',
 'data/split-20240823111724-3.pdf',
 'data/split-20240823111724-4.pdf',
 'data/split-20240823111724-5.pdf',
 'data/split-20240823111724-6.pdf',
 'data/split-20240823111724-7.pdf',
 'data/split-20240823111724-8.pdf',
 'data/split-20240823111724-9.pdf',
 'data/split-20240823111724-10.pdf',
 'data/split-20240823111724-11.pdf',
 'data/split-20240823111724-12.pdf',
 'data/split-20240823111724-13.pdf',
 'data/split-20240823111724-14.pdf',
 'data/split-20240823111724-15.pdf',
 'data/split-20240823111724-16.pdf',
 'data/split-20240823111724-17.pdf']

# %%
processed_pdfs = []
for pdf in pdfs:
    print(f'Processing (OCR) for PDF {pdf}')
    processed_pdf = ocr_pdf(input_pdf_name=pdf)
    processed_pdfs.append(processed_pdf)
# Out:
# Processing (OCR) for PDF data/split-20240823111724-0.pdf
# Inside ocr_pdf function
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting OCR_PDF job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# Processing (OCR) for PDF data/split-20240823111724-1.pdf
# Inside ocr_pdf function
# ...
